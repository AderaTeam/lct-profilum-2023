# %%
import pandas as pd
import re
import tqdm as notebook_tqdm
from transformers import AutoModel, AutoTokenizer
from razdel import tokenize
from string import punctuation
import torch

punctuation += '—'
tokenizer = AutoTokenizer.from_pretrained("ai-forever/sbert_large_nlu_ru")
vectorizer = AutoModel.from_pretrained("ai-forever/sbert_large_nlu_ru")
with open('../DATA/less_semantic_words.txt', 'r', encoding='utf-8') as f:
    stop_words = pd.Series(f.read().split('\n')).unique()

# %%
special_regex = re.compile('\d{2}.\d{2}.\d{2}')
emoj = re.compile('['
                  u'\U0001F600-\U0001F64F'
                  u'\U0001F300-\U0001F5FF'
                  u'\U0001F680-\U0001F6FF'
                  u'\U0001F1E0-\U0001F1FF'
                  u'\U00002500-\U00002BEF'
                  u'\U00002702-\U000027B0'
                  u'\U000024C2-\U0001F251'
                  u'\U0001f926-\U0001f937'
                  u'\U00010000-\U0010ffff'
                  u'\u2640-\u2642'
                  u'\u2600-\u2B55'
                  u'\u200d'
                  u'\u23cf'
                  u'\u23e9'
                  u'\u231a'
                  u'\ufe0f'
                  u'\u3030'
                  ']', re.UNICODE)

# %%
data = pd.read_excel('../DATA/Профессии_ОКСО_ ЛЦТ_Профилум.xlsx', index_col='№')
data.head(3)
# Out:
#                              Отрасль текстом Название профессии  \
# №
# 1                         Агропромышленность            Агроном
# 2  Архитектура, строительство и недвижимость         Маркшейдер
# 3  Архитектура, строительство и недвижимость        Реставратор
#
#   Специальности ОКСО - по одной специальности может быть множетсво программ обучения, которые открывают колледжии и вузы. Специальность - то, что написано у тебя в дипломе после окончания одной из программ обучения.  \
# №
# 1  35.02.05 - Агрономия, 35.03.03 - Агрохимия и а...
# 2  05.03.01 - Геология, 21.05.04 - Горное дело, 2...
# 3  07.02.01 - Архитектура, 54.02.04 - Реставрация...
#
#   Уровень образования. Цифры в середине кода ОКСО хх.ХХ.хх говорят об образовательном уровне: 03 и 05 - высшее образование, 01 и 02 - среднее профессиональное образование  \
# №
# 1  SecondaryEducation,HeigherEducation,HeigherEdu...
# 2  HeigherEducation,HeigherEducation,HeigherEduca...
# 3  SecondaryEducation,SecondaryEducation,Secondar...
#
#                    Описание профессии для 8-9 класса
# №
# 1  Выращивает ягоды, овощи, фрукты, грибы, кормов...
# 2  Исследует месторождения полезных ископаемых, п...
# 3  Восстанавливает старинные здания, сооружения и...

# %%
data.shape
# Out:
# (50, 5)

# %% [markdown]
# # Split iner data

# %%
def spec_symbols_remove_processor(text: str):
    text = re.sub(emoj, '', text)
    text = text.replace('\n', '')
    return text
    

def specials_processor(x):
    v = dict()
    for i, j in zip(re.findall(special_regex, x), re.split(special_regex, x)[1:]):
        v[i] = j.replace(' - ', '')
        v[i] = v[i][:-2] if v[i][-2] == ',' else v[i]
    return v


def data_education_lvl_processor(x):
    return x.split(',')


def dat_description_processor(x):
    x = spec_symbols_remove_processor(x)
    s = x.split('<br><br>')
    v = dict()
    v['main_task'] = s[0]
    v['sub_tasks'] = s[1].split('<br>')
    v['description'] = s[2].split('<br>')[1]
    return v


print(specials_processor('05.03.01 - Геология, 21.05.04 - Горное дело, 21.05.02 - Прикладная геология, 21.05.03 - Технология геологической разведки'))
print(data_education_lvl_processor('HeigherEducation,HeigherEducation,HeigherEducation,HeigherEducation'))
print(data['Описание профессии для 8-9 класса'].apply(dat_description_processor)[1])
# Out:
# {'05.03.01': 'Геология', '21.05.04': 'Горное дело', '21.05.02': 'Прикладная геология', '21.05.03': 'Технология геологической разведки'}
# ['HeigherEducation', 'HeigherEducation', 'HeigherEducation', 'HeigherEducation']
# {'main_task': 'Выращивает ягоды, овощи, фрукты, грибы, кормовые травы и злаковые растения', 'sub_tasks': [' Проверяет почву и оценивает качество семян.', ' Выбирает сорт и культуру для посева.', ' Принимает решение, когда сажать растения и убирать урожай.', ' Организует работу комбайнеров и трактористов: дает им задания и контролирует их выполнение.', ' Увеличивает объем сбора урожая и повышает его качество.'], 'description': 'Представь, что агроном работает на ферме, которая выращивает кукурузу. Специалист обследует почву, изучает погоду и проводит исследования, чтобы узнать, какие удобрения подойдут для кукурузы. Затем он рассказывает фермеру, как и когда применять удобрения. Агроном также проверяет растения на наличие болезней и вредителей. Если он замечает проблемы, то советует фермеру, как обрабатывать кукурузу. Кроме того, агроном помогает фермеру выбрать лучшее время для посева и уборки кукурузы, чтобы получить большой урожай.'}

# %%
data_preprocessed = data.copy(deep=1)
data_preprocessed['Специальности ОКСО'] = data['Специальности ОКСО - по одной специальности может быть множетсво программ обучения, которые открывают колледжии и вузы. Специальность - то, что написано у тебя в дипломе после окончания одной из программ обучения.'].apply(specials_processor)
data_preprocessed['Уровень образования'] = data['Уровень образования. Цифры в середине кода ОКСО хх.ХХ.хх говорят об образовательном уровне: 03 и 05 - высшее образование, 01 и 02 - среднее профессиональное образование'].apply(data_education_lvl_processor)
data_preprocessed['Описание профессии для 8-9 класса'] = data['Описание профессии для 8-9 класса'].apply(dat_description_processor)
data_preprocessed =data_preprocessed.drop(
    [
        'Специальности ОКСО - по одной специальности может быть множетсво программ обучения, которые открывают колледжии и вузы. Специальность - то, что написано у тебя в дипломе после окончания одной из программ обучения.',
        'Уровень образования. Цифры в середине кода ОКСО хх.ХХ.хх говорят об образовательном уровне: 03 и 05 - высшее образование, 01 и 02 - среднее профессиональное образование',
    ],
    axis=1
)
data_preprocessed.head(3)
# Out:
#                              Отрасль текстом Название профессии  \
# №
# 1                         Агропромышленность            Агроном
# 2  Архитектура, строительство и недвижимость         Маркшейдер
# 3  Архитектура, строительство и недвижимость        Реставратор
#
#                    Описание профессии для 8-9 класса  \
# №
# 1  {'main_task': 'Выращивает ягоды, овощи, фрукты...
# 2  {'main_task': 'Исследует месторождения полезны...
# 3  {'main_task': 'Восстанавливает старинные здани...
#
#                                   Специальности ОКСО  \
# №
# 1  {'35.02.05': 'Агрономия', '35.03.03': 'Агрохим...
# 2  {'05.03.01': 'Геология', '21.05.04': 'Горное д...
# 3  {'07.02.01': 'Архитектура', '54.02.04': 'Реста...
#
#                                  Уровень образования
# №
# 1  [SecondaryEducation, HeigherEducation, Heigher...
# 2  [HeigherEducation, HeigherEducation, HeigherEd...
# 3  [SecondaryEducation, SecondaryEducation, Secon...

# %% [markdown]
# # Descriptions processing

# %%
descriptions_df = pd.DataFrame()
descriptions_df['main_task'] = data_preprocessed['Описание профессии для 8-9 класса'].apply(lambda a: a['main_task'])
descriptions_df['sub_tasks'] = data_preprocessed['Описание профессии для 8-9 класса'].apply(lambda a: a['sub_tasks'])
descriptions_df['description'] = data_preprocessed['Описание профессии для 8-9 класса'].apply(lambda a: a['description'])
descriptions_df.head()
# Out:
#                                            main_task  \
# №
# 1  Выращивает ягоды, овощи, фрукты, грибы, кормов...
# 2  Исследует месторождения полезных ископаемых, п...
# 3  Восстанавливает старинные здания, сооружения и...
# 4                   Ремонтирует строительную технику
# 5  Устанавливает и обслуживает системы водоснабже...
#
#                                            sub_tasks  \
# №
# 1  [ Проверяет почву и оценивает качество семян.,...
# 2  [ Исследует горную местность и определяет нали...
# 3  [ Изучает и анализирует старинные произведения...
# 4  [ Ремонтирует строительные машины.,  Проводит ...
# 5  [ Соединяет трубы между собой — так он создает...
#
#                                          description
# №
# 1  Представь, что агроном работает на ферме, кото...
# 2  Допустим, в горах строят тоннель для новой жел...
# 3  Допустим, в городе есть старинное здание. Рест...
# 4  Допустим, на стройплощадке у экскаватора слома...
# 5  Допустим, в новом здании нужно установить сист...

# %%
splited_df = pd.concat([data_preprocessed, descriptions_df], axis=1)
splited_df.head()
# Out:
#                              Отрасль текстом  \
# №
# 1                         Агропромышленность
# 2  Архитектура, строительство и недвижимость
# 3  Архитектура, строительство и недвижимость
# 4  Архитектура, строительство и недвижимость
# 5  Архитектура, строительство и недвижимость
#
#                                   Название профессии  \
# №
# 1                                            Агроном
# 2                                         Маркшейдер
# 3                                        Реставратор
# 4              Слесарь по ремонту строительных машин
# 5  Монтажник санитарно-технических систем и обору...
#
#                    Описание профессии для 8-9 класса  \
# №
# 1  {'main_task': 'Выращивает ягоды, овощи, фрукты...
# 2  {'main_task': 'Исследует месторождения полезны...
# 3  {'main_task': 'Восстанавливает старинные здани...
# 4  {'main_task': 'Ремонтирует строительную техник...
# 5  {'main_task': 'Устанавливает и обслуживает сис...
#
#                                   Специальности ОКСО  \
# №
# 1  {'35.02.05': 'Агрономия', '35.03.03': 'Агрохим...
# 2  {'05.03.01': 'Геология', '21.05.04': 'Горное д...
# 3  {'07.02.01': 'Архитектура', '54.02.04': 'Реста...
# 4  {'23.02.03': 'Техническое обслуживание и ремон...
# 5  {'08.01.26': 'Мастер по ремонту и обслуживанию...
#
#                                  Уровень образования  \
# №
# 1  [SecondaryEducation, HeigherEducation, Heigher...
# 2  [HeigherEducation, HeigherEducation, HeigherEd...
# 3  [SecondaryEducation, SecondaryEducation, Secon...
# 4  [SecondaryEducation, SecondaryEducation, Secon...
# 5  [SecondaryEducation, SecondaryEducation, Secon...
#
#                                            main_task  \
# №
# 1  Выращивает ягоды, овощи, фрукты, грибы, кормов...
# 2  Исследует месторождения полезных ископаемых, п...
# 3  Восстанавливает старинные здания, сооружения и...
# 4                   Ремонтирует строительную технику
# 5  Устанавливает и обслуживает системы водоснабже...
#
#                                            sub_tasks  \
# №
# 1  [ Проверяет почву и оценивает качество семян.,...
# 2  [ Исследует горную местность и определяет нали...
# 3  [ Изучает и анализирует старинные произведения...
# 4  [ Ремонтирует строительные машины.,  Проводит ...
# 5  [ Соединяет трубы между собой — так он создает...
#
#                                          description
# №
# 1  Представь, что агроном работает на ферме, кото...
# 2  Допустим, в горах строят тоннель для новой жел...
# 3  Допустим, в городе есть старинное здание. Рест...
# 4  Допустим, на стройплощадке у экскаватора слома...
# 5  Допустим, в новом здании нужно установить сист...

# %%
from copy import deepcopy
w_d_s = dict()
for i, j, k in zip(splited_df['Название профессии'], splited_df['Описание профессии для 8-9 класса'], splited_df['Специальности ОКСО']):
    b = deepcopy(j)
    b['spec'] = k
    w_d_s[i] = b

# %%
w_d_s
# Out:
# {'Агроном': {'main_task': 'Выращивает ягоды, овощи, фрукты, грибы, кормовые травы и злаковые растения',
#   'sub_tasks': [' Проверяет почву и оценивает качество семян.',
#    ' Выбирает сорт и культуру для посева.',
#    ' Принимает решение, когда сажать растения и убирать урожай.',
#    ' Организует работу комбайнеров и трактористов: дает им задания и контролирует их выполнение.',
#    ' Увеличивает объем сбора урожая и повышает его качество.'],
#   'description': 'Представь, что агроном работает на ферме, которая выращивает кукурузу. Специалист обследует почву, изучает погоду и проводит исследования, чтобы узнать, какие удобрения подойдут для кукурузы. Затем он рассказывает фермеру, как и когда применять удобрения. Агроном также проверяет растения на наличие болезней и вредителей. Если он замечает проблемы, то советует фермеру, как обрабатывать кукурузу. Кроме того, агроном помогает фермеру выбрать лучшее время для посева и уборки кукурузы, чтобы получить большой урожай.',
#   'spec': {'35.02.05': 'Агрономия',
#    '35.03.03': 'Агрохимия и агропочвоведение',
#    '35.03.04': 'Агрономия',
#    '35.03.05': 'Садоводство'}},
#  'Маркшейдер': {'main_task': 'Исследует месторождения полезных ископаемых, помогает при строительстве подземных сооружений',
#   'sub_tasks': [' Исследует горную местность и определяет наличие полезных ископаемых под землей.',
#    ' Проводит исследования рельефа, горных пород и подземных вод, чтобы определить точные размеры и формы горных образований.',
#    ' Составляет планы для определения границ месторождений полезных ископаемых и предотвращения возможных опасностей при их добыче.',
#    ' Определяет оптимальные места для строительства и разрабатывает планы расположения объектов.',
#    ' Ведет документацию и создает карты, на которых отмечены все измерения и находки.'],
#   'description': 'Допустим, в горах строят тоннель для новой железной дороги. Маркшейдер приезжает на стройку и начинает свою работу. Он изучает гору, чтобы понять, где можно пробурить тоннель и какие сложности могут при этом возникнуть. С помощью специальных инструментов, например измерительных лент и теодолитов, маркшейдер определяет точные размеры горы и составляет план строительства. Также он учитывает геологические данные, чтобы знать, какая порода находится под землей и как с ней работать.',
#   'spec': {'05.03.01': 'Геология',
#    '21.05.04': 'Горное дело',
#    '21.05.02': 'Прикладная геология',
#    '21.05.03': 'Технология геологической разведки'}},
#  'Реставратор': {'main_task': 'Восстанавливает старинные здания, сооружения и предметы искусства: мебель, картины, скульптуры и фрески',
#   'sub_tasks': [' Изучает и анализирует старинные произведения искусства, их историю и особенности. ',
#    '\xa0Советуется с историками, химиками и другими экспертами, чтобы выбрать лучшие материалы и методы работы.',
#    ' Восстанавливает и ремонтирует древние каменные стены, деревянные элементы и уникальные детали зданий. ',
#    ' Воспроизводит и восстанавливает оригинальные цвета, узоры и орнаменты и воссоздает первоначальный вид картины, фрески или здания. ',
#    ' Проводит исследования и находит способы защиты произведений искусства от разрушительного воздействия окружающей среды. '],
#   'description': 'Допустим, в городе есть старинное здание. Реставратору поручают восстановить его первоначальный вид. Сначала специалист изучит историю здания и соберет все доступные сведения о его архитектуре. Затем он начнет реставрацию, используя специальные инструменты и материалы. Если какая-то часть здания повреждена или испорчена временем, реставратор займется ее восстановлением с учетом исторической точности. Он также будет внимательно работать над деталями, чтобы сохранить уникальные элементы здания. В результате старинное здание будет выглядеть так, как будто оно только построено.',
#   'spec': {'07.02.01': 'Архитектура',
#    '54.02.04': 'Реставрация',
#    '54.01.17': 'Реставратор строительный',
#    '54.01.19': 'Реставратор памятников каменного и деревянного зодчества',
#    '07.03.01': 'Архитектура',
#    '07.03.02': 'Реконструкция и реставрация архитектурного наследия',
#    '54.03.04': 'Реставрация',
#    '54.05.02': 'Живопись'}},
#  'Слесарь по ремонту строительных машин': {'main_task': 'Ремонтирует строительную технику',
#   'sub_tasks': [' Ремонтирует строительные машины.',
#    ' Проводит техническое обслуживание машин, предотвращает поломки.',
#    ' Заменяет старые детали на новые, совершенствует работу машин.'],
#   'description': 'Допустим, на стройплощадке у экскаватора сломался ковш. Оператор машины свяжется со слесарем по ремонту строительных машин. Специалист приедет на стройку с инструментами и запасными деталями. Он разберет ковш, чтобы понять, какая именно деталь сломалась, и заменит ее на новую. Затем он соберет ковш обратно и проверит, исправно ли он работает.',
#   'spec': {'23.02.03': 'Техническое обслуживание и ремонт автомобильного транспорта',
#    '23.02.04': 'Техническая эксплуатация подъемно-транспортных, строительных, дорожных машин и оборудования (по отраслям)',
#    '23.02.07': 'Техническое обслуживание и ремонт двигателей, систем и агрегатов автомобилей',
#    '23.01.08': 'Слесарь по ремонту строительных машин'}},
#  'Монтажник санитарно-технических систем и оборудования': {'main_task': 'Устанавливает и обслуживает системы водоснабжения, канализации и отопления',
#   'sub_tasks': [' Соединяет трубы между собой — так он создает систему водоснабжения или канализации.',
#    ' Устанавливает сантехнику, например раковины, унитазы и душевые кабины.',
#    ' Регулирует и проверяет систему отопления и обеспечивает комфортную температуру в помещении.',
#    ' Отслеживает и устраняет утечки и поломки в системах.'],
#   'description': 'Допустим, в новом здании нужно установить систему водоснабжения и канализации. Монтажник санитарно-технических систем и оборудования сначала изучит схему водоснабжения и канализации здания, затем уложит трубы и соединит их между собой, вмонтирует вентили. После этого он установит сантехнические приборы — раковины, краны и унитазы. Он также проверит систему на отсутствие протечек. Когда все будет готово, монтажник предоставит заказчику отчет о проделанной работе.',
#   'spec': {'08.01.26': 'Мастер по ремонту и обслуживанию инженерных систем жилищно-коммунального хозяйства',
#    '08.01.14': 'Монтажник санитарно-технических, вентиляционных систем и оборудования',
#    '08.02.07': 'Монтаж и эксплуатация внутренних сантехнических устройств, кондиционирования воздуха и вентиляции',
#    '08.01.10': 'Мастер жилищно-коммунального хозяйства',
#    '08.01.29': 'Мастер по ремонту и обслуживанию инженерных систем жилищно-коммунального хозяйства'}},
#  'Военнослужащий': {'main_task': 'Защищает граждан и территории от внутренних и внешних угроз',
#   'sub_tasks': [' Оценивает военно-политическую ситуацию, прогнозирует вооруженные конфликты.',
#    ' Выполняет приказы командира или сам командует ротой.',
#    ' Работает в разных направлениях: защита границ, техническое обслуживание и ремонт военной техники, лечение и реабилитация раненых солдат.'],
#   'description': 'В мирное время военнослужащий тренирует других людей в военной организации и поддерживает технику в состоянии готовности. Для этого он регулярно занимается на полигоне, где оттачивает навыки использования разного оружия и взаимодействия в команде. В условиях военного времени он выполняет боевые задачи. Военнослужащие имеют разные права и обязанности в зависимости от рода войск, звания и занимаемой должности. Они могут быть преподавателями в военных институтах, а также работать на оборонных и стратегически важных предприятиях.',
#   'spec': {'23.05.02': 'Транспортные средства специального назначения',
#    '24.05.01': 'Проектирование, производство и эксплуатация ракет и ракетно-космических комплексов',
#    '11.03.02': 'Инфокоммуникационные технологии и системы связи',
#    '11.02.10': 'Радиосвязь, радиовещание и телевидение',
#    '09.05.01': 'Применение и эксплуатация автоматизированных систем специального назначения',
#    '17.05.04': 'Управление техническим обеспечением войск (сил)',
#    '56.05.03': 'Служебно-прикладная физическая подготовка',
#    '56.05.02': 'Радиационная, химическая и биологическая защита'}},
#  'Бизнес-аналитик': {'main_task': 'Анализирует данные, чтобы помочь компании принять правильные решения',
#   'sub_tasks': [' Анализирует большие объемы информации о продукте или услуге, чтобы понять, как их можно улучшить.',
#    ' Создает отчеты, графики и диаграммы, чтобы показать данные наглядно и сделать из них выводы.',
#    ' Дает рекомендации по улучшению работы компании на основе данных и результатов анализа.'],
#   'description': 'Представь, что небольшой ресторан хочет увеличить прибыль. Бизнес-аналитик начинает работу с того, что анализирует данные о продажах, затратах на продукты и оплате работы персонала. Затем он создает отчеты с графиками, чтобы показать, какие блюда и напитки приносят больше прибыли. На основе этих данных бизнес-аналитик дает рекомендации, какие блюда следует добавить в меню, а какие нужно убрать. Также он советует сократить затраты на продукты и персонал, чтобы увеличить прибыль ресторана. Благодаря работе бизнес-аналитика руководство ресторана принимает правильные решения и повышает эффективность бизнеса.',
#   'spec': {'38.03.01': 'Экономика',
#    '38.03.02': 'Менеджмент',
#    '38.03.05': 'Бизнес-информатика'}},
#  'Маркетолог': {'main_task': 'Продвигает товары и услуги, делает так, чтобы люди захотели их приобрести',
#   'sub_tasks': [' Изучает конкурентов, анализирует поведение покупателей и выявляет товары и услуги, на которые больше спрос.',
#    ' Придумывает идеи для продвижения товаров и услуг.',
#    ' Создает тексты для рекламы, например для постов в социальных сетях или баннеров на сайтах.',
#    ' Планирует и запускает рекламу в социальных сетях и на ТВ.'],
#   'description': 'Допустим, компания производит удобные рюкзаки. Маркетолог проводит исследование, чтобы понять, что именно понравится людям в этих рюкзаках, например большой объем и прочность. Затем маркетолог придумает рекламу, в которой раскроет преимущества товара. Он создаст яркие посты с фотографиями людей, которые носят рюкзаки, и разместит их в социальных сетях. Также маркетолог напишет тексты для рекламы или закажет их у копирайтера. Все это поможет компании продавать больше рюкзаков и стать более узнаваемой.',
#   'spec': {'42.02.01': 'Реклама',
#    '38.02.04': 'Коммерция (по отраслям)',
#    '42.03.01': 'Реклама и связи с общественностью',
#    '39.03.01': 'Социология',
#    '38.03.02': 'Менеджмент',
#    '09.03.02': 'Информационные системы и технологии'}},
#  'Менеджер по продажам': {'main_task': 'Продает товары и услуги, находит новых клиентов и заключает с ними сделки',
#   'sub_tasks': [' Узнает потребности клиентов и убеждает их приобрести товары или услуги компании.',
#    ' Поддерживает постоянную связь с клиентами, рассказывает о товарах и услугах.',
#    ' Изучает предложения конкурентов, чтобы понимать, какие продукты пользуются большим спросом.'],
#   'description': 'Представь, что компания выпустила новый продукт — умные часы. Компании нужно разместить свой товар в магазинах, чтобы люди смогли его купить. В этом поможет менеджер по продажам. Специалист проанализирует, есть ли потенциальные клиенты для этих часов и где их можно найти, — например, в магазине электроники. Он найдет несколько магазинов, которые заинтересованы в продаже умных часов. Затем он договорится о закупке часов, чтобы магазин выставил товар на продажу. Менеджер также помогает рекламировать продукты и участвует в организации промоакций, чтобы привлечь больше клиентов.',
#   'spec': {'38.03.07': 'Товароведение',
#    '38.03.06': 'Торговое дело',
#    '38.03.02': 'Менеджмент',
#    '38.03.01': 'Экономика',
#    '42.03.01': 'Реклама и связи с общественностью',
#    '42.03.05': 'Медиакоммуникации',
#    '38.02.04': 'Коммерция (по отраслям)'}},
#  'Digital-маркетолог': {'main_task': 'Продвигает товары и услуги компании в интернете, социальных сетях, на цифровом телевидении',
#   'sub_tasks': [' Digital — в переводе с английского «цифровой». Относится к компьютерам, технологиям, интернету.',
#    ' Digital-маркетолог анализирует данные о целевой аудитории, то есть для кого будет реклама и исследует что сейчас популярно в Сети.',
#    ' Сравнивает, какие рекламные материалы работают лучше и приводят больше клиентов.',
#    '\xa0Пишет бриф, то есть задание для специалистов по рекламе, копирайтеров и дизайнеров, затем управляет рекламными кампаниями — покупает размещение рекламы в Сети.',
#    ' Занимается социальными сетями, создает интересные посты и рекламные акции, чтобы люди узнавали о продукте.'],
#   'description': 'Допустим, у компании есть новый продукт — умные наушники. Digital-маркетолог думает, как можно рассказать о них людям. Он создает интересную рекламу, в которой показывает, как наушники выглядят и насколько хороший у них звук. Затем он размещает эту рекламу на сайтах и в социальных сетях. Когда люди видят рекламу, они могут кликнуть по ней и перейти на сайт компании, чтобы узнать больше о наушниках и, возможно, купить их. Digital-маркетолог следит за тем, сколько людей кликает по рекламе и покупает наушники, и, если товар не продается, он меняет рекламу на более привлекательную.',
#   'spec': {'42.02.01': 'Реклама',
#    '38.02.04': 'Коммерция (по отраслям)',
#    '42.03.01': 'Реклама и связи с общественностью',
#    '39.03.01': 'Социология',
#    '38.03.02': 'Менеджмент',
#    '42.03.05': 'Медиакоммуникации'}},
#  'Контент-менеджер': {'main_task': 'Управляет контентом в соцсетях и на сайте компании или бренда, пишет тексты и обрабатывает изображения и видео',
#   'sub_tasks': [' Находит интересные материалы для сайта или соцсетей.',
#    ' Заполняет карточки товаров, обновляет цены, запускает акции, если компания продает товары или услуги.',
#    ' Работает с отделом разработки, предлагает варианты улучшения сайта: новые разделы, категории, параметры товаров.',
#    ' Ставит задачи исполнителям, например копирайтерам или дизайнерам, следит за соблюдением сроков, контролирует качество работы на всех этапах.'],
#   'description': 'Представь, что есть сайт о животных, и на нем нужно опубликовать статью о корме для взрослых котов. Контент-менеджер соберет информацию по теме из различных источников. Он найдет статьи, фотографии и видео о корме и выберет только достоверные материалы. Затем на основании найденных фактов он закажет статью у копирайтера. Когда статья будет написана, контент-менеджер добавит к ней фотографии и видео. После этого он загрузит статью на сайт.',
#   'spec': {'42.02.01': 'Реклама',
#    '38.03.02': 'Менеджмент',
#    '38.03.06': 'Торговое дело',
#    '42.03.01': 'Реклама и связи с общественностью',
#    '42.03.02': 'Журналистика',
#    '42.03.03': 'Издательское дело',
#    '42.03.05': 'Медиакоммуникации',
#    '45.03.01': 'Филология',
#    '45.03.02': 'Лингвистика',
#    '44.03.05': 'Педагогическое образование (с двумя профилями подготовки)'}},
#  'Медсестра | Медбрат': {'main_task': 'Помогает врачу, ухаживает за пациентами, проводит лечебные процедуры',
#   'sub_tasks': [' Ставит уколы, капельницы, перевязывает раны, дает лекарства.',
#    ' Помогает врачу вести прием больных.',
#    ' Работает в больницах, поликлиниках и других медицинских учреждениях.'],
#   'description': 'Если человек попадает в больницу или приходит в поликлинику, то диагноз ему поставит врач, а ухаживать за пациентом будет медсестра. Медсестра заботится о потребностях своего пациента, выслушивает жалобы и передает их врачу, ставит уколы, дает лекарства, делает перевязки. Медсестра — один из незаменимых специалистов в больнице, потому что именно она проводит с больными больше всего времени.',
#   'spec': {'34.01.01': 'Младшая медицинская сестра по уходу за больными',
#    '34.02.01': 'Сестринское дело',
#    '31.02.01': 'Лечебное дело',
#    '31.02.02': 'Акушерское дело',
#    '34.03.01': 'Сестринское дело'}},
#  'Врач': {'main_task': 'Обследует и лечит людей',
#   'sub_tasks': [' Помогает людям оставаться здоровыми.',
#    ' Работает в государственных больницах, поликлиниках или в частных клиниках.',
#    ' Занимается профилактикой и лечением болезней.',
#    ' Прописывает лекарства, проводит операции.'],
#   'description': 'Врач — многопрофильный специалист, например, он может специализироваться на болезнях сердца. Тогда такой врач будет называться кардиологом. Специалист проводит осмотры, измеряет давление, расспрашивает о симптомах, дает направление на дальнейшие обследования. После этого он ставит точный диагноз и назначает лечение.',
#   'spec': {'31.05.01': 'Лечебное дело',
#    '31.05.02': 'Педиатрия',
#    '31.05.03': 'Стоматология',
#    '31.05.04': 'Остеопатия',
#    '30.05.02': 'Медицинская биофизика'}},
#  'Реабилитолог': {'main_task': 'Помогает восстановить организм пациента после операции, болезни или травмы',
#   'sub_tasks': [' Составляет план лечения и сотрудничает с другими врачами — массажистами, тренерами по лечебной физкультуре.',
#    ' Разрабатывает комплекс процедур для пациента, дает советы по уходу за больным его родственникам.',
#    ' Работает с людьми, перенесшими инсульт, спортивную травму или автомобильную аварию.'],
#   'description': 'Допустим, что человек сломал ногу, пока играл в футбол. Ему пришлось носить гипс в течение нескольких недель, пока кость не срослась. Теперь, когда гипс сняли, ему трудно ходить без боли. Тут на помощь приходит реабилитолог. Специалист оценивает травму и разрабатывает план, который поможет восстановить силы и подвижность ноги. План может включать упражнения для укрепления мышц ноги, растяжки для улучшения гибкости и методики, которые помогут ходить без боли и прихрамывания. После периода реабилитации пациент снова сможет играть в футбол.',
#   'spec': {'31.02.03': 'Лабораторная диагностика',
#    '31.02.01': 'Лечебное дело',
#    '34.02.01': 'Сестринское дело',
#    '49.02.02': 'Адаптивная физическая культура',
#    '31.05.01': 'Лечебное дело',
#    '31.05.02': 'Педиатрия'}},
#  'Фельдшер': {'main_task': 'Оказывает пациентам первую доврачебную помощь и ставит предварительный диагноз',
#   'sub_tasks': [' Работает в скорой помощи: помогает в экстренных ситуациях и оказывает первую помощь.',
#    ' Обследует пациентов, измеряет давление и температуру, делает уколы.',
#    ' Общается с пациентами, выясняет их симптомы и жалобы.',
#    ' Изучает результаты обследований и медицинскую карту пациента, чтобы принять решение о дальнейшем лечении.'],
#   'description': 'Фельдшер диагностирует болезни и лечит пациентов, чего не вправе делать медсестра. При этом он не проводит операции, как врач. Фельдшер принимает пациентов в больницах и поликлиниках, работает в скорой помощи и в поездках, например, в экспедициях. Фельдшер осматривает пациентов, выслушивает жалобы и ставит предварительный диагноз. Он помогает всем, кто нуждается в лечении и помощи: например, если у пациента повышенная температура и болит горло, фельдшер может проверить, есть ли у него простуда. А если человек ранен, останавливает кровь и обрабатывает рану. Именно фельдшер проверяет наличие необходимых лекарств и медикаментов перед поездкой и в машине скорой помощи.',
#   'spec': {'31.02.01': 'Лечебное дело',
#    '32.02.01': 'Медико-профилактическое дело'}},
#  'AI-тренер': {'main_task': 'Тренирует компьютерную программу — искусственный интеллект, чтобы он стал «умнее»',
#   'sub_tasks': [' AI (от английского artificial intelligence) или ИИ (искусственный интеллект) — программа, выполняющая задачи, которые обычно выполняют люди, например: сбор информации, творческие решения, логические рассуждения.',
#    ' Обучает искусственный интеллект так же, как это делают учителя в школе, только вместо книг и тетрадей использует технические данные и программы.',
#    ' Разрабатывает алгоритмы и программы, чтобы компьютеры могли сами учиться и\xa0делать выводы из большого количества информации.',
#    ' Исследует новые технологии в области искусственного интеллекта и предлагает новые идеи для его развития.'],
#   'description': 'Допустим, искусственный интеллект учится распознавать разные цвета. AI-тренер разрабатывает специальную программу, которая поможет искусственному интеллекту понять, где какой цвет. Он покажет искусственному интеллекту много разных картинок с разными цветами и объяснит, какие цвета на них изображены. После этого AI-тренер проверит, насколько хорошо искусственный интеллект научился распознавать цвета, и, если нужно, подкорректирует программу, чтобы улучшить его навыки. AI-тренер продолжит тренировать искусственный интеллект и помогать ему развиваться, чтобы он распознавал цвета без ошибок.',
#   'spec': {'45.03.01': 'Филология',
#    '42.03.02': 'Журналистика',
#    '42.03.03': 'Издательское дело',
#    '45.03.02': 'Лингвистика'}},
#  'Архитектор интеллектуальных систем управления беспилотного транспорта': {'main_task': 'Создает умные системы управления беспилотными машинами и поездами',
#   'sub_tasks': [' Создает программы, с помощью которых автомобили смогут ездить без водителя.',
#    ' Улучшает специальные приложения и системы, чтобы люди могли управлять беспилотными транспортными средствами.',
#    ' Выстраивает порядок работы программ, которые собирают и анализируют  данные от различных датчиков.',
#    ' Анализирует данные и собирает информацию, чтобы сделать беспилотные транспортные системы еще лучше.'],
#   'description': 'Представь, что компания хочет сделать автобусы, которые будут ездить без водителей. Она нанимает архитектора интеллектуальных систем управления беспилотного транспорта. Он начинает работу с изучения требований и пожеланий компании. Затем разрабатывает особые программы и приложения, которые будут управлять автобусами. Он создает программы, чтобы автобусы могли самостоятельно определять свой маршрут, останавливаться на остановках и безопасно перевозить пассажиров. Важно, чтобы автобусы были «умными» и могли справиться с любыми ситуациями на дороге.',
#   'spec': {'01.03.02': 'Прикладная математика и информатика',
#    '01.03.04': 'Прикладная математика',
#    '09.03.02': 'Информационные системы и технологии',
#    '15.03.06': 'Мехатроника и робототехника',
#    '27.03.04': 'Управление в технических системах',
#    '09.03.03': 'Прикладная информатика',
#    '09.03.01': 'Информатика и вычислительная техника',
#    '23.03.01': 'Технология транспортных процессов'}},
#  'Промпт-инженер': {'main_task': 'Создает правильные запросы искусственному интеллекту, чтобы он генерировал тексты, код и картинки',
#   'sub_tasks': ['\xa0Промпт\xa0(от англ. prompt — «подсказка», «запрос») — это команда или запрос, которые мы адресуем искусственному интеллекту.',
#    ' Составляет задачи и сообщения для нейросетей.',
#    ' Говорит с нейросетями на их языке, чтобы получить нужный ответ.',
#    ' Изучает новые методы и алгоритмы, чтобы нейросети могли обучаться и работать быстрее и эффективнее.',
#    ' Анализирует данные и результаты работы нейросетей, чтобы понять, как улучшить их и сделать полезнее для людей.'],
#   'description': 'Допустим, писатель хочет, чтобы искусственный интеллект написал сказку. Он обращается к промпт-инженеру. Специалист создает специальный запрос, который помогает нейросетям понять, какие слова и какие фразы использовать. Например, он пишет: «Расскажи сказку про принцессу и дракона», чтобы нейросеть поняла, про кого ей нужно придумать историю. Потом промпт-инженер пишет запрос, чтобы помочь компьютеру составить сказку. Он может написать: «Расскажи о принцессе, которая спасает деревню от злого дракона». Он будет придумывать и изменять запросы до тех пор, пока искусственный интеллект не выдаст нужный результат.',
#   'spec': {'01.03.02': 'Прикладная математика и информатика',
#    '09.03.02': 'Информационные системы и технологии',
#    '38.03.05': 'Бизнес-информатика',
#    '45.03.04': 'Интеллектуальные системы в гуманитарной сфере'}},
#  'Инженер IoT': {'main_task': 'Проектирует умные устройства, которые взаимодействуют друг с другом через интернет',
#   'sub_tasks': [' Разрабатывает программы, которые позволяют устройствам обмениваться информацией и принимать команды на расстоянии.',
#    ' Программирует приложения и веб-сервисы, чтобы люди управляли устройствами с помощью своих смартфонов.',
#    ' Разрабатывает системы умного дома, где все устройства работают сообща: от освещения до кондиционера.'],
#   'description': 'Представь, что ты живешь в умном доме, где все устройства взаимосвязаны. Например, когда ты выходишь из комнаты, свет автоматически выключается, а кондиционер снижает интенсивность работы, чтобы экономить энергию. Такие системы создает инженер IoT. Он разрабатывает специальные устройства, которые могут подключаться к интернету и обмениваться информацией. Например, он может создать умную лампу, которая меняет цвет и яркость, и ты можешь управлять ей с помощью своего смартфона. Также инженер IoT разрабатывает приложения, чтобы люди могли управлять устройствами и получать информацию об их работе. Он заботится о том, чтобы все устройства работали вместе и обеспечивали удобство и безопасность для людей. Благодаря инженеру IoT наши дома становятся комфорнее.',
#   'spec': {'01.03.02': 'Прикладная математика и информатика',
#    '09.03.01': 'Информатика и вычислительная техника',
#    '27.03.04': 'Управление в технических системах',
#    '09.03.03': 'Прикладная информатика',
#    '11.03.02': 'Инфокоммуникационные технологии и системы связи',
#    '15.03.04': 'Автоматизация технологических процессов и производств'}},
#  'Системный аналитик': {'main_task': 'Анализирует задачи бизнеса и устройство информационных систем, чтобы улучшить работу компании и ее IT-продукт',
#   'sub_tasks': [' Разрабатывает технические требования, например, определяет, что должна делать программа и как быстро.',
#    ' Изучает возможные риски и проблемы при внедрении нового программного обеспечения.',
#    ' Составляет отчеты, схемы и диаграммы, чтобы показать, насколько эффективно работает компания и ее программное обеспечение.',
#    ' Выступает посредником между различными отделами компании и IT-специалистами.'],
#   'description': 'Предположим, менеджер компании хочет создать программу, чтобы сотрудники разных отделов могли ставить задачи друг другу. Системный аналитик сначала узнает у сотрудников, нужна ли им такая программа, и если да, то какие функции они хотят в ней видеть. Если сотрудники считают, что она не нужна, системный аналитик объяснит менеджеру, что создание программы может стать пустой тратой денег. Если же сотрудникам нужна такая программа, системный аналитик определит технические требования к ней и составит техническое задание для разработчиков. Если в компании уже используется какая-то программа для совместной работы, системный аналитик выяснит, можно ли в нее добавить новую функцию.',
#   'spec': {'09.03.02': 'Информационные системы и технологии',
#    '09.03.03': 'Прикладная информатика',
#    '27.03.03': 'Системный анализ и управление',
#    '15.03.04': 'Автоматизация технологических процессов и производств',
#    '38.03.05': 'Бизнес-информатика'}},
#  'Frontend-разработчик': {'main_task': 'Создает внешний вид сайта с помощью кода',
#   'sub_tasks': [' Frontend (англ. «передняя часть») — все элементы сайта, которые видит пользователь, такие как меню, кнопки, текст, изображения, карточки товаров, формы и анимация.',
#    ' Frontend-разработчик с помощью кода создает дизайн, цвета и оформление, придуманные веб-дизайнером.',
#    ' Настраивает сайт под разные устройства и размеры экранов.',
#    ' Тестирует и устраняет ошибки на сайте или в приложении.'],
#   'description': 'Цель frontend-разработчика — создавать красивые и удобные сайты. Для этого он использует свои знания в программировании и веб-дизайне. Сначала он разрабатывает веб-страницы и их структуру: с помощью кода размещает разные элементы (текст, картинки, видео и другие) в нужных местах. Затем frontend-разработчик добавляет стили — цвета, шрифты, рамки, логотипы. После этого он может сделать некоторые части сайта динамичными — например, если нажать на кнопку «лайк», то она поменяет цвет и число лайков увеличится. Разработчик также следит, чтобы сайт отображался правильно на телефоне и планшете, а не только на компьютере.',
#   'spec': {'09.02.03': 'Программирование в компьютерных системах',
#    '09.02.05': 'Прикладная информатика (по отраслям)',
#    '09.02.07': 'Информационные системы и программирование',
#    '09.03.02': 'Информационные системы и технологии',
#    '09.03.03': 'Прикладная информатика',
#    '54.03.01': 'Дизайн',
#    '09.03.04': 'Программная инженерия',
#    '01.03.02': 'Прикладная математика и информатика'}},
#  'Специалист по машинному обучению': {'main_task': 'Обучает искусственный интеллект на тысячах примеров',
#   'sub_tasks': ['\xa0Помогает компьютеру учиться.',
#    '\xa0Собирает и обрабатывает большие объемы данных, например чтобы искусственный интеллект мог отличить кошек от собак.',
#    '\xa0Работает с инженерами-программистами, специалистами по обработке данных и математиками.'],
#   'description': 'Специалист обучает искусственный интеллект решать сложные задачи в повседневной жизни. Например, он разработает навигатор, который построит кратчайший маршрут от школы до дома с учетом пробок и ремонта дорог.',
#   'spec': {'01.03.02': 'Прикладная математика и информатика',
#    '01.03.04': 'Прикладная математика',
#    '02.03.01': 'Математика и компьютерные науки',
#    '02.03.02': 'Фундаментальная информатика и информационные технологии',
#    '02.03.03': 'Математическое обеспечение и администрирование информационных систем',
#    '09.03.01': 'Информатика и вычислительная техника',
#    '09.03.03': 'Прикладная информатика',
#    '38.03.05': 'Бизнес-информатика',
#    '09.02.04': 'Информационные системы (по отраслям)',
#    '09.02.05': 'Прикладная информатика (по отраслям)',
#    '09.02.07': 'Информационные системы и программирование',
#    '09.03.02': 'Информационные системы и технологии'}},
#  'Разработчик баз данных': {'main_task': 'Создает базы данных — хранилища для информации компании',
#   'sub_tasks': [' Разрабатывает структуру базы данных и стандарты хранения информации.',
#    ' Определяет, какая информация будет храниться в базе данных и в каком формате.',
#    ' Создает скрипты (мини-программы) для работы с информацией в базе данных.',
#    ' Настраивает базу данных для быстрого и удобного доступа к информации.'],
#   'description': 'Сначала разработчик баз данных общается с заказчиком, чтобы понять, какую информацию нужно хранить и как ей будут пользоваться. Затем он разрабатывает структуру базы данных, в которой определяет содержание таблиц: например, одна таблица может показывать все товары, которые купил клиент, и даты покупок, а другая — все покупки одного товара и отзывы о нем. Он придумывает такую структуру хранения информации, чтобы другие люди тоже смогли работать с базой данных, и создает инструкции и приложения, которые позволяют быстро и легко искать и изменять данные.',
#   'spec': {'01.03.02': 'Прикладная математика и информатика',
#    '01.03.04': 'Прикладная математика',
#    '09.03.01': 'Информатика и вычислительная техника'}},
#  'Разработчик мобильных приложений': {'main_task': 'Создает приложения для смартфонов, планшетов и смарт-часов',
#   'sub_tasks': [' Пишет код для приложений: от игр и соцсетей до навигаторов и онлайн-банков.',
#    ' Думает о том, как приложение будет выглядеть, как будет работать и принесет ли пользу людям.',
#    ' Проверяет приложение на наличие ошибок.'],
#   'description': 'Для мобильных телефонов существует множество игр или приложений. Чтобы все работало как надо: не вылетало, не зависало, все кнопки нажимались — разработчик мобильных приложений пишет код. Он превращает картинки, которые сделал дизайнер, в работающее приложение.',
#   'spec': {'38.03.05': 'Бизнес-информатика',
#    '02.03.03': 'Математическое обеспечение и администрирование информационных систем',
#    '09.03.01': 'Информатика и вычислительная техника',
#    '09.03.02': 'Информационные системы и технологии',
#    '09.03.03': 'Прикладная информатика',
#    '09.03.04': 'Программная инженерия',
#    '01.03.02': 'Прикладная математика и информатика'}},
#  'Аналитик данных': {'main_task': 'Ищет закономерности в поведении людей на сайте и в приложении',
#   'sub_tasks': [' Анализирует различные данные, например сколько людей заходит на сайт магазина каждый день.',
#    '\xa0Превращает огромные таблицы в красивые диаграммы и графики.',
#    '\xa0Делает предположения, что можно улучшить на сайте или в приложении.'],
#   'description': 'Аналитик данных похож на синоптика: они оба собирают информацию для составления прогнозов. Синоптик собирает данные о температуре воздуха, давлении и других погодных явлениях, чтобы предсказать, какой будет погода. Аналитик данных собирает данные о продажах, мнениях клиентов или другую информацию, чтобы сделать сервис более удобным для людей. Выводы, которые делает специалист, помогают владельцам бизнеса принимать правильные решения.',
#   'spec': {'01.03.01': 'Математика',
#    '02.03.01': 'Математика и компьютерные науки',
#    '01.03.02': 'Прикладная математика и информатика',
#    '01.03.04': 'Прикладная математика',
#    '09.03.03': 'Прикладная информатика',
#    '01.03.05': 'Статистика',
#    '38.03.01': 'Экономика',
#    '38.03.05': 'Бизнес-информатика'}},
#  'Швея-закройщица': {'main_task': 'Раскраивает и сшивает ткани и кожу на производстве одежды, обуви или аксессуаров',
#   'sub_tasks': [' Изучает выкройки, лекала и схемы, чтобы понять, как сшить вещь.',
#    ' Понимает особенности разных материалов, умеет выявить брак, знает принципы и технологии создания одежды.',
#    ' Снимает мерки и выбирает ткань для будущего изделия.',
#    ' Владеет техниками раскроя, пошива и ремонта текстильных изделий.'],
#   'description': 'Допустим, магазину нужны новые куртки для сотрудников. Швея-закройщица сначала изучает выкройки курток, чтобы понять, как их сшить. Затем она выбирает ткань подходящего цвета и раскраивает ее — режет на куски нужного размера и формы. Швея соединяет куски ткани между собой — сшивает их с помощью швейной машинки. Она проверяет, чтобы все швы были ровными, а на ткани не было складок. Когда все детали готовы, швея-закройщица соединяет их, чтобы получилась готовая куртка. Также она пришивает к куртке карманы, молнии или пуговицы.',
#   'spec': {'29.03.01': 'Технология изделий легкой промышленности',
#    '29.01.05': 'Закройщик',
#    '29.01.08': 'Оператор швейного оборудования',
#    '29.01.17': 'Оператор вязально-швейного оборудования'}},
#  'Фрезеровщик': {'main_task': 'Управляет специальным инструментом — фрезерным станком',
#   'sub_tasks': [' Фрезерный станок — большой стол с панелью управления, пилами и резаками. Он может разрезать дерево или металл с высокой точностью.',
#    '  Фрезеровщик кладет железный или деревянный лист на фрезеровочный стол, выбирает нужный инструмент, например пилу, и запускает программу, чтобы пила вырезала нужные детали.',
#    ' Точно измеряет и проверяет готовую деталь на соответствие требованиям.',
#    ' Осматривает оборудование, проводит техническое обслуживание и регулярно чистит станок, чтобы он работал исправно.'],
#   'description': 'Представь, что нужно изготовить деталь для самолета. Фрезеровщик возьмет металлическую заготовку и закрепит ее на станке. Затем он установит нужный фрезерный инструмент, правильно разместит заготовку, включит программу и запустит процесс фрезерования. Он будет следить за каждым движением станка, чтобы деталь получилась идеальной формы и размера. После завершения работы он измерит готовую деталь. Фрезеровщик также заботится о своем оборудовании, регулярно чистит его и проводит техническое обслуживание, чтобы всегда быть готовым к работе.',
#   'spec': {'15.01.32': 'Оператор станков с программным управлением',
#    '15.01.34': 'Фрезеровщик на станках с числовым программным управлением'}},
#  'Разработчик беспилотных систем управления': {'main_task': 'Тестирует программы для управления беспилотными машинами, самолетами и дронами без участия человека',
#   'sub_tasks': [' Проектирует алгоритмы, чтобы системы работали надежно и безопасно и реагировали на разные ситуации.',
#    ' Определяет оптимальную скорость для машин на разных участках дороги с учетом погоды.',
#    ' Предусматривает множество возможных ситуаций и сценариев, чтобы беспилотный автомобиль был готов к ним.',
#    ' Сотрудничает с инженерами и дизайнерами, чтобы создавать инновационные и удобные системы управления.'],
#   'description': 'Допустим, компании нужно создать автомобиль, который будет ездить без водителя. Для этого компания наймет разработчика беспилотных систем управления. Сначала специалист изучает все требования и задачи. Затем он программирует специальную систему, которая будет управлять автомобилем. Разработчик создает алгоритмы, которые будут указывать автомобилю, когда и как ехать, когда тормозить и как реагировать на другие машины на дороге. После этого разработчик проведет тестирование программы, чтобы убедиться, что она работает правильно. Он использует компьютерные модели или специальные симуляторы и проверяет, что беспилотный автомобиль ведет себя безопасно в разных ситуациях на дороге. Когда программа готова, разработчик передает ее инженерам, которые установят ее в автомобиль. Затем компания выпустит беспилотный автомобиль на дороги, и он сможет ездить самостоятельно, не требуя участия водителя.',
#   'spec': {'15.03.06': 'Мехатроника и робототехника',
#    '15.03.03': 'Прикладная механика',
#    '15.03.01': 'Машиностроение',
#    '01.03.02': 'Прикладная математика и информатика',
#    '09.03.02': 'Информационные системы и технологии'}},
#  'Сварщик': {'main_task': 'Соединяет металлические детали между собой',
#   'sub_tasks': [' Расплавляет металл с помощью сварочного аппарата и соединяет детали в единое целое.',
#    ' Режет, шлифует и обрабатывает металлические детали перед сваркой, чтобы они лучше соединялись.',
#    ' Читает чертежи и инструкции, чтобы правильно сварить детали, и проверяет готовый сварочный шов на дефекты.'],
#   'description': 'Представь, что нужно сделать велосипедную раму, которая состоит из соединенных друг с другом металлических трубок. Сначала специалист подготавливает металлические трубки, очищает их от грязи, устраняет повреждения. Затем он включает сварочный аппарат и начинает плавить металл, держа его на безопасном расстоянии. Как только металл становится жидким, сварщик соединяет трубки. На месте стыка получается прочный сварочный шов. Готовую раму сварщик проверяет, чтобы убедиться, что она крепкая и надежная.',
#   'spec': {'15.01.05': 'Сварщик (ручной и частично механизированной сварки (наплавки)',
#    '15.01.06': 'Сварщик на лазерных установках',
#    '22.02.06': 'Сварочное производство'}},
#  'Инженер-механик': {'main_task': 'Проектирует, налаживает и ремонтирует механическое оборудование на производстве',
#   'sub_tasks': [' Ремонтирует оборудование и механизмы. Например, если сломался конвейер на заводе, инженер должен понять источник поломки, разобрать прибор, снять сломанную деталь, измерить ее, сделать чертеж и заказать новую.',
#    ' Налаживает и настраивает механические машины и инструменты, чтобы они работали правильно и без сбоев.',
#    ' Дает экспертную оценку состояния текущего оборудования и может порекомендовать к закупке новое.'],
#   'description': 'Допустим, на большом заводе производят автомобили. Инженер-механик на этом производстве настраивает механизмы, которые используются на производственной линии. Он планирует, как должны работать разные детали, чтобы автомобили собирались быстро и качественно. Когда оборудование установлено, инженер-механик следит за его работой, чтобы оно не ломалось и работало исправно. Если вдруг что-то перестает работать, специалист сразу же приходит на помощь и устраняет поломку. Он также постоянно ищет способы улучшения оборудования, чтобы производство стало еще эффективнее.',
#   'spec': {'15.03.01': 'Машиностроение',
#    '15.03.02': 'Технологические машины и оборудование',
#    '13.03.03': 'Энергетическое машиностроение',
#    '23.03.02': 'Наземные транспортно-технологические комплексы',
#    '23.05.02': 'Транспортные средства специального назначения',
#    '15.03.05': 'Конструкторско-технологическое обеспечение машиностроительных производств',
#    '15.03.06': 'Мехатроника и робототехника',
#    '23.03.03': 'Эксплуатация транспортно-технологических машин и комплексов',
#    '23.05.01': 'Наземные транспортно-технологические средства',
#    '15.05.01': 'Проектирование технологических машин и комплексов',
#    '15.03.03': 'Прикладная механика',
#    '18.03.02': 'Энерго- и ресурсосберегающие процессы в химической технологии, нефтехимии и биотехнологии',
#    '24.03.05': 'Двигатели летательных аппаратов',
#    '21.05.04': 'Горное дело',
#    '17.05.02': 'Стрелково-пушечное, артиллерийское и ракетное оружие',
#    '26.05.06': 'Эксплуатация судовых энергетических установок',
#    '44.03.04': 'Профессиональное обучение (по отраслям)',
#    '24.05.01': 'Проектирование, производство и эксплуатация ракет и ракетно-космических комплексов'}},
#  'Мастер контрольно-измерительных приборов и автоматики': {'main_task': 'Отвечает за установку, обслуживание и ремонт измерительных приборов на производстве',
#   'sub_tasks': [' Создает новые измерительные приборы и устанавливает их на производственные линии.',
#    ' Проверяет работу установленных приборов и автоматических систем.',
#    ' Ремонтирует и обслуживает измерительные приборы.'],
#   'description': 'Допустим, на большой фабрике производят автомобили. Каждый день на производственных линиях из сотен деталей собирают машины. Мастер контрольно-измерительных приборов и автоматики создает и устанавливает специальные приборы, которые помогают следить за сборкой машин. Кроме того, мастер проверяет исправность уже установленных приборов. Если что-то на производственной линии не работает, он ремонтирует или заменяет приборы. Благодаря работе специалиста автомобили производятся быстро и по всем стандартам безопасности.',
#   'spec': {'27.02.04': 'Автоматические системы управления',
#    '15.01.31': 'Мастер контрольно-измерительных приборов и автоматики'}},
#  'Электромеханик': {'main_task': 'Налаживает и ремонтирует промышленное оборудование',
#   'sub_tasks': [' Разбирает различные устройства, чтобы найти и исправить проблемы.',
#    ' Устанавливает и подключает электромеханическое оборудование по инструкциям и стандартам безопасности.',
#    ' Тестирует электромеханические устройства, чтобы убедиться в их работоспособности и безопасности.'],
#   'description': 'Представь, что на производстве автомобилей есть конвейер, по которому перемещают детали. Электромеханик отвечает за обслуживание и ремонт различных компонентов конвейера, например моторов, приводов, редукторов и систем управления. Специалист также устанавливает новые компоненты и настраивает параметры конвейера, чтобы детали на конвейере ехали с оптимальной скоростью. Например, если возникнет проблема с двигателем конвейера, электромеханик проведет диагностику, выяснит причину неисправности, а затем отремонтирует или заменит двигатель.',
#   'spec': {'13.02.11': 'Техническая эксплуатация и обслуживание электрического и электромеханического оборудования (по отраслям)',
#    '13.01.10': 'Электромонтер по ремонту и обслуживанию электрооборудования (по отраслям)',
#    '15.02.01': 'Монтаж и техническая эксплуатация промышленного оборудования (по отраслям)',
#    '23.02.05': 'Эксплуатация транспортного электрооборудования и автоматики (по видам транспорта, за исключением водного)',
#    '26.02.06': 'Эксплуатация судового электрооборудования и средств автоматики',
#    '15.01.17': 'Электромеханик по торговому и холодильному оборудованию',
#    '27.02.03': 'Автоматика и телемеханика на транспорте (железнодорожном транспорте)',
#    '15.03.01': 'Машиностроение',
#    '13.03.02': 'Электроэнергетика и электротехника'}},
#  'Специалист по производству и обслуживанию авиатехники': {'main_task': 'Производит и обслуживает самолеты, выявляет и устраняет неисправности',
#   'sub_tasks': [' Разбирается в схемах и чертежах, грамотно собирает оборудование.',
#    ' Тестирует и контролирует системы и компоненты самолетов: выполняет межполетную подготовку, меняет топливо, расходные материалы, устраняет дефекты, проверяет электронику, состояние деталей и обшивки.',
#    ' Исправляет поломки самолетов, чтобы обеспечить безопасность полетов.'],
#   'description': 'Допустим, есть самолет, который нужно проверить и подготовить к полету. Специалист осмотрит каждую часть самолета, чтобы убедиться, что все работает исправно. Он проверит двигатели, электрические системы, а также работу всех кнопок и выключателей. Если он найдет проблему, он устранит ее. Специалист заменит неисправные детали и выполнит все необходимые ремонтные работы.',
#   'spec': {'12.02.01': 'Авиационные приборы и комплексы',
#    '25.02.06': 'Производство и обслуживание авиационной техники'}},
#  'Оператор станков с программным управлением': {'main_task': 'Настраивает работу станка и контролирует его работу с помощью пульта управления',
#   'sub_tasks': [' Стоит за пультом управления — большим экраном, вокруг которого множество кнопок и переключателей.',
#    ' Выбирает режимы и настройки станка для обработки деталей точно по параметрам.',
#    ' Ремонтирует и технически обслуживает механизмы станка.'],
#   'description': 'Станки с программным управлением — это большие устройства, которые могут по-разному изменять детали без физической силы человека: нажал на кнопку — и все работает само: пила пилит, сверло сверлит. Для управления таким станком нужен оператор. Он контролирует весь процесс работы: устанавливает необходимые инструменты на станок и запускает его дистанционно с помощью пульта управления. Затем оператор проверяет результат обработки. Если что-то идет не так, он быстро устраняет проблему.',
#   'spec': {'15.01.32': 'Оператор станков с программным управлением',
#    '15.01.25': 'Станочник (металлообработка)',
#    '15.01.26': 'Токарь-универсал',
#    '15.01.27': 'Фрезеровщик-универсал'}},
#  'Инженер-робототехник': {'main_task': 'Исследует, проектирует и программирует роботов',
#   'sub_tasks': [' Проектирует механических помощников, которые выполняют различные задачи: пылесосят, летают, снимают видео, отвечают на вопросы и многое другое.',
#    ' Программирует роботов, выбирает для них детали и материалы, собирает все воедино.',
#    ' Изучает сенсоры, искусственный интеллект и другие технологии для повышения производительности, надежности и безопасности роботов.',
#    ' Экспериментирует с программами, деталями и механизмами вместе с физиками, инженерами-конструкторами, программистами и другими специалистами.',
#    ' Разрабатывает роботов для дома и дачи, армии и полиции, медицины, сельского хозяйства и других сфер.'],
#   'description': 'Представь, что на большой выставке, на которую съехались люди из многих стран, поставили робота-помощника, который умеет ходить и говорить. Этот робот помогает людям разобраться в экспозициях, найти дорогу к выходу или кафе, провожает их туда и отвечает на любые вопросы о выставке. Инженер-робототехник сделал этого робота «живым» с помощью специальных программ. Одна из них распознает речь, другая — объекты, третья анализирует данные и управляет движениями и речью робота. Чтобы робот мог передвигаться, инженер разработал особые механизмы и сенсоры, а чтобы он мог говорить, установил микрофон и динамик. В результате у организаторов выставки появился умный помощник, который знает все о выставке, говорит на разных иностранных языках, приветлив и не устает.',
#   'spec': {'15.03.06': 'Мехатроника и робототехника',
#    '15.03.03': 'Прикладная механика',
#    '15.02.10': 'Мехатроника и мобильная робототехника (по отраслям)',
#    '15.02.11': 'Техническая эксплуатация и обслуживание роботизированного производства'}},
#  'Дошкольный педагог': {'main_task': 'Обучает и воспитывает детей младше семи лет',
#   'sub_tasks': [' Учит ребят различать цифры, буквы, геометрические формы для подготовки к школе.',
#    ' Организует детские спектакли, экскурсии и игры, чтобы дети разносторонне развивались.',
#    ' Создает дружелюбную атмосферу, в которой дети могут учиться и расти в комфорте и безопасности.',
#    ' Общается с родителями, чтобы совместно работать над воспитанием и обучением ребенка.'],
# ...
#   'description': 'Допустим, инженер-технолог работает на заводе по переработке нефти, который производит бензин. Технолог заметил, что после обновления инструкций рабочие завода начали допускать мелкие ошибки. Инженер проанализировал ситуацию и понял, что это происходит из-за сложных и длинных этапов производства. Тогда он решил автоматизировать производство и тем самым сократить число ошибок. Вместе с другими инженерами он спроектировал новые аппараты для анализа качества топлива и автоматизировал производство с помощью специального оборудования и программ. После ввода новой системы инженер-технолог протестировал ее эффективность, а затем обучил сотрудников завода новым методам работы. Теперь трудиться стало гораздо легче — большую часть времени работники проводят в диспетчерской, где наблюдают за показателями приборов на компьютерах.',
#   'spec': {'18.03.01': 'Химическая технология',
#    '18.05.02': 'Химическая технология материалов современной энергетики',
#    '18.05.01': 'Химическая технология энергонасыщенных материалов и изделий'}},
#  'Кассир': {'main_task': 'Помогает клиентам оплачивать товары, принимает от них деньги, выдает сдачу',
#   'sub_tasks': [' Работает с деньгами и кассовым аппаратом.',
#    ' Сканирует товар, проверяет качество продукции, делает замену.',
#    ' Считает общую стоимость всех товаров с помощью компьютера.',
#    ' Принимает оплату от клиента в виде наличных или банковской карты.'],
#   'description': 'Представь, что вы с семьей пошли в магазин. После того как вы соберете продуктовую корзину, вы придете на кассу. Там вас встретит кассир. Он работает с компьютером и специальным сканером, который считывает штрихкоды товаров. Как только кассир просканирует все товары, компьютер подсчитает сумму. Специалист сообщит вам, сколько денег нужно заплатить. Затем кассир примет у вас оплату наличными или банковской картой.',
#   'spec': {'38.02.01': 'Экономика и бухгалтерский учет (по отраслям)',
#    '38.01.03': 'Контролер банка',
#    '38.01.02': 'Продавец, контролер-кассир',
#    '43.02.06': 'Сервис на транспорте (по видам транспорта)',
#    '43.01.05': 'Оператор по обработке перевозочных документов на железнодорожном транспорте'}},
#  'Менеджер по работе с маркетплейсами': {'main_task': 'Организует продажи товаров на маркетплейсах и помогает продавцам вести онлайн-бизнес',
#   'sub_tasks': [' Маркетплейс — это очень большой интернет-магазин, где продавцы размещают свои товары, а покупатели выбирают лучшие предложения.',
#    ' Менеджер размещает товары на маркетплейсе, например на Ozon, Wildberries, Яндекс Маркете, и следит за их актуальностью и показами на сайте.',
#    ' Обрабатывает фотографии товаров и создает описания, чтобы привлечь покупателей.',
#    ' Общается с клиентами, отвечает на их вопросы и помогает решить проблемы с заказами.',
#    ' Анализирует данные о продажах и предлагает продавцам способы увеличить прибыль.'],
#   'description': 'Допустим, магазин сувениров продает футболки с уникальными рисунками. Чтобы продавать их в интернете, магазин нанимает менеджера по работе с маркетплейсами. Специалист размещает фотографии футболок на сайте маркетплейса и придумывает привлекательные описания к ним. Он обрабатывает фотографии в специальных программах, чтобы они были четкими и передавали цвет изделия. Менеджер отвечает на вопросы пользователей платформы о товаре, как сделать заказ, помогает с выбором. Он старается помочь каждому клиенту и решить все проблемы быстро и дружелюбно. Менеджер по работе с маркетплейсами изучает статистику продаж и предлагает решения для увеличения прибыли.',
#   'spec': {'42.02.01': 'Реклама',
#    '38.02.04': 'Коммерция (по отраслям)',
#    '38.03.01': 'Экономика',
#    '38.03.02': 'Менеджмент'}},
#  'Машинист поезда': {'main_task': 'Управляет поездом и обеспечивает безопасную перевозку пассажиров и грузов',
#   'sub_tasks': [' Подготавливает поезд к рейсу, проверяет работу двигателя и состояние вагонов.',
#    ' Проверяет исправность тормозного оборудования.',
#    ' Проверяет свободность железнодорожного пути, следит за сигналами семафоров.',
#    ' Обеспечивает безопасность пассажиров, следит за правильным закрытием и открытием дверей.',
#    ' Соблюдает расписание и принимает решения о скорости движения поезда.'],
#   'description': 'Представь, что ты едешь на поезде из одного города в другой. За безопасность и комфорт твоей поездки отвечает машинист поезда. Перед рейсом он проверяет работу оборудования. Затем он садится в кабину управления и начинает движение. Машинист поезда обязательно следит за сигнальными знаками и соблюдает правила движения. Если возникают неисправности, например двери не закрывается или поезд остановился, машинист принимает необходимые меры и связывается с другими членами экипажа или диспетчерским центром. Машинист завершит свою смену, когда поезд прибудет в пункт назначения.',
#   'spec': {'23.01.09': 'Машинист локомотива'}},
#  'Водитель': {'main_task': 'Перевозит людей и грузы по назначенному маршруту',
#   'sub_tasks': [' Управляет автомобилем и проводит много времени за рулем.',
#    ' Специализируется на одном из направлений: дальнобойщик — перевозит грузы в другие города и страны, таксист — возит пассажиров по их маршрутам, водитель общественного транспорта — едет по заданному маршруту и в день перевозит сотни пассажиров.',
#    ' Планирует маршруты, чтобы попасть в нужное место быстро и безопасно.',
#    ' Проверяет техническое состояние машины, заправляет ее топливом и меняет масло.'],
#   'description': 'Представь, что ты с классом едешь на экскурсию на автобусе. Водитель пришел на работу рано утром и проверил автобус: он убедился, что двигатель работает хорошо, все двери открываются и закрываются, а фары светят ярко. Затем он подготовил маршрут на карте, чтобы вы прибыли на место назначения как можно быстрее. Во время поездки водитель следит за дорожными знаками и ограничениями скорости, чтобы не попасть в аварию и не подвергнуть пассажиров опасности.',
#   'spec': {'23.01.03': 'Автомеханик',
#    '23.01.04': 'Водитель городского электротранспорта'}},
#  'Оператор беспилотных аппаратов': {'main_task': 'Управляет беспилотниками, например дронами или квадрокоптерами',
#   'sub_tasks': [' Запускает дроны, чтобы доставить товары или собрать информацию о местности.',
#    ' Планирует маршрут и следит за движением дрона при помощи специальных программ и прикрепленной к дрону камере.',
#    ' Обслуживает и ремонтирует беспилотные устройства, чтобы они всегда были готовы к работе.'],
#   'description': 'Допустим, оператору поручили с помощью дронов осмотреть, как растут посевы на полях. Он введет в специальную программу координаты поля и отправит беспилотный аппарат на нужную точку. Дрон оснащен камерой и другими приборами, которые позволяют ему собирать информацию о состоянии растений и почвы на поле. С помощью камеры специалист сделает фотографии и видео высокого разрешения, которые помогут оценить состояние растений на поле. Оператор проследит за тем, чтобы беспилотный аппарат летел в нужном направлении и делал все необходимые снимки. Если что-то перестанет работать, оператор может в любой момент изменить настройки программы или направить аппарат обратно на базу для диагностики и ремонта.',
#   'spec': {'25.02.08': 'Эксплуатация беспилотных авиационных систем',
#    '24.03.02': 'Системы управления движением и навигация',
#    '24.03.04': 'Авиастроение',
#    '23.03.03': 'Эксплуатация транспортно-технологических машин и комплексов',
#    '24.05.05': 'Интегрированные системы летательных аппаратов',
#    '24.05.06': 'Системы управления летательными аппаратами',
#    '25.03.03': 'Аэронавигация',
#    '24.03.01': 'Ракетные комплексы и космонавтика',
#    '24.05.01': 'Проектирование, производство и эксплуатация ракет и ракетно-космических комплексов'}},
#  'Автомеханик': {'main_task': 'Ремонтирует и обслуживает автомобили',
#   'sub_tasks': [' Проверяет работу двигателя, меняет масло и фильтры.',
#    ' Диагностирует неисправности в машинах и устраняет их.',
#    ' Меняет детали и запчасти, которые вышли из строя.',
#    ' Обслуживает тормозную систему и рулевое управление.'],
#   'description': 'Представь, что вы с семьей готовитесь к долгому путешествию на автомобиле. Чтобы во время поездки автомобиль не сломался, его нужно отправить на проверку автомеханику. Специалист быстро и точно проведет диагностику с помощью специальных приборов, например сканеров. Если автомеханик найдет неисправности, то устранит их, чтобы на автомобиле можно было безопасно ездить. Специалист знает особенности каждой марки машины и подбирает для ремонта необходимые запчасти.',
#   'spec': {'23.02.07': 'Техническое обслуживание и ремонт двигателей, систем и агрегатов автомобилей',
#    '23.02.05': 'Эксплуатация транспортного электрооборудования и автоматики (по видам транспорта, за исключением водного)',
#    '23.02.03': 'Техническое обслуживание и ремонт автомобильного транспорта',
#    '44.02.06': 'Профессиональное обучение (по отраслям)',
#    '23.01.03': 'Автомеханик',
#    '23.01.17': 'Мастер по ремонту и обслуживанию автомобилей'}},
#  'Инженер по обслуживанию автотранспорта': {'main_task': 'Следит за техническим состоянием автотранспорта в автопарке и отвечает за его ремонт в автосервисе',
#   'sub_tasks': [' Организует техническое обслуживание и ремонт автомобилей в автопарке.',
#    ' Разрабатывает схемы и графики движения автотранспортных средств.',
#    ' Проводит мероприятия по обновлению состава автомобилей, автобусов, грузовиков или фур.',
#    ' Разрабатывает стандарты и правила по проведению технического обслуживания и ремонта автомобилей.',
#    ' Работает вместе с экспедиторами, чтобы организовать доставку товаров.'],
#   'description': 'Допустим, в городе нужно организовать движение автобусов. Инженер по обслуживанию автотранспорта составляет график движения автобусов и разрабатывает оптимальный маршрут. Он учитывает время движения, чтобы транспортные средства приходили без опозданий. Также инженер следит за тем, чтобы автопарк был в хорошем техническом состоянии. Он проверяет, все ли автобусы работают исправно, и если они ломаются, то организует ремонт. Инженер по обслуживанию заботится о том, чтобы автопарк был современным и безопасным, например он следит, чтобы старые автобусы вовремя заменяли на новые.',
#   'spec': {'23.02.03': 'Техническое обслуживание и ремонт автомобильного транспорта',
#    '23.03.01': 'Технология транспортных процессов',
#    '23.03.02': 'Наземные транспортно-технологические комплексы',
#    '13.03.03': 'Энергетическое машиностроение',
#    '08.03.01': 'Строительство',
#    '21.05.04': 'Горное дело',
#    '35.03.06': 'Агроинженерия',
#    '15.03.02': 'Технологические машины и оборудование',
#    '23.05.02': 'Транспортные средства специального назначения',
#    '44.03.04': 'Профессиональное обучение (по отраслям)',
#    '23.03.03': 'Эксплуатация транспортно-технологических машин и комплексов',
#    '23.05.01': 'Наземные транспортно-технологические средства',
#    '43.03.01': 'Сервис'}},
#  'Бухгалтер': {'main_task': 'Составляет документы для налоговой, начисляет зарплаты сотрудникам, следит, чтобы в документах не было ошибок',
#   'sub_tasks': [' Считает доходы и расходы компании, знает, сколько денег остается после оплаты всех расходов.',
#    ' Составляет отчеты о доходах и расходах компании в компьютерной программе.',
#    ' Изучает финансовые документы и проверяет, правильно ли они заполнены.'],
#   'description': 'Представь, что компания занимается продажей фруктов и овощей. Бухгалтер правильно учитывает все финансовые потоки. Он подсчитывает, сколько денег компания получила от продажи фруктов, а сколько потратила на закупку овощей или оплату аренды магазина. Бухгалтер работает в компьютерной программе, в которую вносит данные о финансовых операциях. Он анализирует эти данные, чтобы помочь руководству принимать правильные решения. Например, если бухгалтер заметит, что люди стали меньше покупать фрукты и овощи, то порекомендует компании меньше закупать продуктов и снизить расходы.',
#   'spec': {'38.02.01': 'Экономика и бухгалтерский учет (по отраслям)',
#    '38.02.06': 'Финансы',
#    '38.03.02': 'Менеджмент',
#    '38.03.01': 'Экономика'}},
#  'Разработчик систем компьютерного зрения': {'main_task': 'Создает программы, которые помогают компьютерам «видеть» и понимать мир вокруг них',
#   'sub_tasks': [' Создает специальные программы для компьютеров, для распознавания и анализа изображения и видео.',
#    ' Обрабатывает материалы, полученные с камер и сенсоров.',
#    ' Тестирует программы распознавания объектов компьютерами.',
#    ' Оптимизирует системы компьютерного зрения, чтобы они работали быстрее и точнее.'],
#   'description': 'Допустим, разработчик систем компьютерного зрения должен создать программу распознавания лиц людей на фотографиях. Он пишет специальный код, который будет обрабатывать изображения и искать на них особенности, характерные для разных лиц. Он применит свои знания математики и программирования и создаст алгоритмы, с помощью которых компьютер будет «видеть» лица так же, как человек. Затем он протестирует программу на разных фотографиях. При обнаружении ошибок или неточностей разработчик изменит код и протестирует программу заново.',
#   'spec': {'01.03.02': 'Прикладная математика и информатика',
#    '09.03.01': 'Информатика и вычислительная техника',
#    '12.03.01': 'Приборостроение',
#    '15.03.06': 'Мехатроника и робототехника',
#    '09.03.03': 'Прикладная информатика',
#    '09.03.02': 'Информационные системы и технологии'}},
#  'Радиоинженер': {'main_task': 'Разрабатывает и обслуживает системы связи и передачи информации по радиоволнам',
#   'sub_tasks': [' Разрабатывает и устанавливает радиосистемы для передачи сигналов на малые и большие расстояния.',
#    ' Подключает антенны, радиопередатчики и радиоприемники, чтобы обеспечить стабильную связь.',
#    ' Ремонтирует и настраивает оборудование.',
#    ' Исследует и тестирует новые технологии, чтобы улучшить связь и расширить ее диапазон.'],
#   'description': 'Допустим, радиоинженер работает над созданием вышек сотовой связи, чтобы мы могли общаться по мобильным телефонам. Сначала радиоинженер изучает территорию и определяет места для новых вышек. Затем он разрабатывает план размещения вышек, определяет их количество, расстояние и высоту, чтобы обеспечить наилучшее покрытие сигнала. После этого он устанавливает вышки, а также другое необходимое оборудование — базовые станции (ретрансляторы, приемопередатчики и антенны). После установки радиоинженер тестирует оборудование, настраивает его, проверяет качество сигнала, чтобы все работало без сбоев.',
#   'spec': {'11.05.01': 'Радиоэлектронные системы и комплексы',
#    '11.03.01': 'Радиотехника',
#    '11.05.02': 'Специальные радиотехнические системы',
#    '11.03.02': 'Инфокоммуникационные технологии и системы связи',
#    '11.02.03': 'Эксплуатация оборудования радиосвязи и электрорадионавигации судов',
#    '11.02.04': 'Радиотехнические комплексы и системы управления космических летательных аппаратов',
#    '11.02.18': 'Системы радиосвязи, мобильной связи и телевидения'}},
#  'Регулировщик радиоэлектронной аппаратуры и приборов': {'main_task': 'Настраивает Wi-Fi-роутеры, ТВ-антенны и другую технику',
#   'sub_tasks': ['  Знает сотни моделей электроники и их частей: печатных плат, генераторов, измерителей и их электронных компонентов.',
#    ' Отвечает за то, чтобы все устройства работали правильно.',
#    ' Может быстро изучить техническую документацию и по ней настроить аппаратуру.'],
#   'description': 'Регулировщик настраивает различные радио- и электронные устройства так, чтобы они правильно работали. Например, радио в автомобиле настроил регулировщик. Он проверил, что радиоприемник работает исправно, а сигнал радио передается на правильной частоте и мощности. Для этого регулировщик использовал специальные приборы, которые позволили ему измерить частоту и мощность сигнала.',
#   'spec': {'11.01.01': 'Монтажник радиоэлектронной аппаратуры и приборов',
#    '11.02.01': 'Радиоаппаратостроение',
#    '11.02.02': 'Техническое обслуживание и ремонт радиоэлектронной техники (по отраслям)',
#    '12.02.03': 'Радиоэлектронные приборные устройства',
#    '12.03.01': 'Приборостроение'}}}

# %%
import json
with open('../DATA/work_spec_desc.json', 'w') as f:
    json.dump(w_d_s, f)

# %%
def clear_from_stopwords(text, sw):
    text = text
    tokens = list(tokenize(text))
    t = []
    for i in tokens:
        if len(i.text) > 2:
            if i.text not in sw:
                t.append(i.text)

    return ' '.join(t)

# %%
def clear_from_stopwords_bin(text, sw):
    text = text
    tokens = list(tokenize(text))
    t = []
    for i in tokens:
        t.append(int(len(i.text) > 2 and i.text not in sw))
    return t

# %% [markdown]
# # Small desc emb

# %%
cleared_desciptions = splited_df['description'].apply(lambda a: a.lower()).apply(lambda a: clear_from_stopwords(a, sw=stop_words)).apply(lambda a: len(a.split()))
cleared_desciptions.max(), cleared_desciptions.mean(), cleared_desciptions.median(), cleared_desciptions.min()
# Out:
# (65, 42.16, 41.0, 15)

# %%
enc = tokenizer(splited_df['description'].apply(lambda a: a.lower()).apply(lambda a: clear_from_stopwords(a, sw=stop_words)).to_list(), padding=True, truncation=True, pad_to_multiple_of=65, max_length=65, return_tensors='pt')

# %%
vec_desc = vectorizer(**enc)[0]

# %%
vec_desc.shape
# Out:
# torch.Size([50, 65, 1024])

# %%
torch.save(vec_desc, '../DATA/small_description_vectors.pt')

# %% [markdown]
# # large desc emb

# %%
long_desciptions = (splited_df['main_task'] + splited_df['sub_tasks'].apply(lambda a: '. '.join(a)) + splited_df['description']).apply(lambda a: a.lower()).apply(lambda a: clear_from_stopwords(a, sw=stop_words))

# %%
cleared_long_desciptions = long_desciptions.apply(lambda a: a.lower()).apply(lambda a: clear_from_stopwords(a, sw=stop_words))
cleared_long_desciptions.apply(lambda a: len(a.split())).max(), cleared_long_desciptions.apply(lambda a: len(a.split())).mean(), cleared_long_desciptions.apply(lambda a: len(a.split())).median(), cleared_long_desciptions.min()
# Out:
# (110,
#  76.58,
#  78.5,
#  'анализирует данные помочь компании принять правильные решения анализирует большие объемы информации продукте услуге улучшить создает отчеты графики диаграммы показать данные наглядно выводы рекомендации улучшению компании основе данных результатов анализа небольшой ресторан увеличить прибыль бизнес-аналитик начинает работу анализирует данные продажах затратах продукты оплате персонала создает отчеты графиками показать какие блюда напитки приносят прибыли основе данных бизнес-аналитик рекомендации какие блюда добавить какие убрать советует сократить затраты продукты персонал увеличить прибыль ресторана благодаря работе бизнес-аналитика руководство ресторана принимает правильные решения повышает эффективность')

# %%
long_enc = tokenizer(cleared_long_desciptions.to_list(), padding=True, truncation=True, pad_to_multiple_of=80, max_length=80, return_tensors='pt')
vec_long_desc = vectorizer(**long_enc)[0]
torch.save(vec_desc, '../DATA/long_description_vectors.pt')

# %% [markdown]
# # Specials processing

# %%
specials_texts = pd.Series(sum(data_preprocessed['Специальности ОКСО'].apply(lambda a: list(a.values())).to_list(), []))
specials_nums = pd.Series(sum(data_preprocessed['Специальности ОКСО'].apply(lambda a: list(a.keys())).to_list(), []))
specials_df = pd.DataFrame({'num': specials_nums, 'name': specials_texts}).drop_duplicates()
specials_df.loc[specials_df['name'].apply(lambda a: specials_df['name'].value_counts()[a]>1), :]
# specials_texts.unique().shape, specials_texts.shape, specials_nums.unique()
# Out:
#           num                                               name
# 0    35.02.05                                          Агрономия
# 2    35.03.04                                          Агрономия
# 8    07.02.01                                        Архитектура
# 9    54.02.04                                        Реставрация
# 12   07.03.01                                        Архитектура
# 14   54.03.04                                        Реставрация
# 20   08.01.26  Мастер по ремонту и обслуживанию инженерных си...
# 24   08.01.29  Мастер по ремонту и обслуживанию инженерных си...
# 66   34.02.01                                   Сестринское дело
# 67   31.02.01                                      Лечебное дело
# 69   34.03.01                                   Сестринское дело
# 70   31.05.01                                      Лечебное дело
# 178  44.03.04            Профессиональное обучение (по отраслям)
# 205  44.02.06            Профессиональное обучение (по отраслям)

# %%
list_of_spec = specials_df.drop_duplicates()
list_of_spec['index'] = list(range(list_of_spec.shape[0]))
list_of_spec.to_csv('../DATA/list_of_spec.csv', index=0)
list_of_spec.head()
# Out:
#         num                          name  index
# 0  35.02.05                     Агрономия      0
# 1  35.03.03  Агрохимия и агропочвоведение      1
# 2  35.03.04                     Агрономия      2
# 3  35.03.05                   Садоводство      3
# 4  05.03.01                      Геология      4

# %%
specials_enum = data_preprocessed['Специальности ОКСО'].apply(lambda a: sum([list_of_spec['index'][list_of_spec['num']==i].to_list() for i in a.keys()], []))
specials_oh = specials_enum.apply(lambda a: torch.nn.functional.one_hot(torch.tensor(a), list_of_spec.shape[0]).sum(dim=0).unsqueeze(0))
data_preprocessed['specials'] = specials_oh

# %%
d = []
for i in list_of_spec['num']:
    d.append(' '.join(cleared_long_desciptions[data_preprocessed['Специальности ОКСО'].apply(lambda a: i in a)]))

# %%
list_of_spec['desc'] = d

# %%
list_of_spec.to_csv('../DATA/spec_num_name_pairs.csv', index=0)

# %%
# long_enc_spec = tokenizer(d, padding=True, truncation=True, pad_to_multiple_of=512, max_length=512, return_tensors='pt')
# vec_long_spec_desc = vectorizer(**long_enc_spec)[0]
# torch.save(vec_long_spec_desc, '../DATA/spec_desc_vec.pt')

# %%
torch.save(torch.cat(data_preprocessed['specials'].to_list()), '../DATA/oh_specials.pt')
